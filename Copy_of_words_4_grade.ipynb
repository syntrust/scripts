# %% [markdown]
# <a href="https://colab.research.google.com/github/syntrust/scripts/blob/main/Copy_of_words_4_grade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
data = {
"机器":"machine",
"欢迎":"welcome",
"炸薯片":"crisp",
"先生":"sir",
"马铃薯、土豆":"potato",
"危险的":"dangerous",
"放、安放、放置":"put",
"等；等待":"wait",
"各自；每个":"each",
"便宜的":"cheap",
"昂贵的":"expensive",
"发送、寄":"send",
"电子邮件":"email",
"花费、价钱为":"cost",
"一百":"hundred",
"呼喊、大叫":"shout",
"狼":"wolf",
"（sheep的复数形式）绵羊":"sheep",
"（run的过去式）跑":"ran",
"从前":"once upon a time",
"照顾、照料":"look after",
"厌倦的；厌烦的":"bored",
"乡村":"village",
"人人、每人":"everyone",
"笑":"laugh",
"谎话、谎言":"lie",
"（learn的过去式）学习":"learnt",
"教训；一节课":"lesson",
"进入……里面":"into",
"月份、月":"month",
"奶酪":"cheese",
"惊恐的、害怕的":"scared",
"逃走、逃跑":"run away",
"音乐会":"concert",
"小提琴":"violin",
"吉他":"guitar",
"紧张的":"nervous",
"结束":"end",
"感到自豪的 、感到骄傲的":"proud",
"意想不到的礼物、意外之事、惊奇":"surprise",
"听见":"hear",
"特别的":"special",
"父亲节":"Father's Day",
"便条、信、口信":"message",
"非常好的、令人愉快的":"great",
"新闻报道":"report",
"粘贴":"stick",
"极好的、极出色的":"fantastic",
"有趣的":"fun",
"与……见面":"meet",
"东、东方、东部":"east",
"西、西方、西部":"west",
"……点钟":"o'clock",
"时间":"time",
"动画片":"cartoon",
"非常、很":"much",
"上午":"am",
"下午":"pm",
"最好的":"best",
"北、北方、北部":"north",
"南、 南方、南部":"south",
"休息":"rest",
"休息一下":"have a rest",
"国家":"country",
"说（某种语言）":"speak",
"首都":"capital",
"也许、大概":"maybe",
"地图":"map",
"因为":"because",
"语言":"language",
"澳大利亚的":"Australian",
"袋鼠":"kangaroo",
"后面的":"back",
"明信片":"postcard",
"计划":"plan",
"博物馆":"museum",
"餐馆、饭店":"restaurant",
}
duration = []
score = 0
def check_word(guess,answer):
  global score
  attempt=1 # attempt是尝试的次数
  while attempt<=3: # 只要while后面的条件成立，就一直循环
    # print("attempt =", attempt)
    if guess == answer:
      score = score+1
      print('Corrct answer. score=', score)
      return
    if attempt == 3:
      print('Sorry. The correct answer is ' + answer)
      return
    guess=input('Wrong. You\'ve got {0} chances. '.format(3-attempt))
    attempt=attempt+1

for k in data:
  # print("k =",k,data[k])
  T1 = time.time()
  guess=input('{0} => '.format(k))
  T2 = time.time()
  check_word(guess,data[k])
  dure = T2 - T1
  duration.append(dure)
  print('使用时间:%s秒' % dure)

print("All set! Congratulations!!")
print('duration', duration)
# Out:
# 机器 => machine
# Corrct answer. score= 1
# 使用时间:5.178117275238037秒
# duration %a [5.178117275238037]
# 欢迎 => welcome
# Corrct answer. score= 2
# 使用时间:4.2033021450042725秒
# duration %a [5.178117275238037, 4.2033021450042725]
# 炸薯片 => cripts
# Wrong. You've got 2 chances. crisps
